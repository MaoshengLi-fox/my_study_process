# %%
from pypdf import  PdfWriter

# 需要合并的 PDF 文件（按顺序）
pdf_files = [r"C:\Users\86182\Desktop\math_hw4.pdf",r"C:\Users\86182\Desktop\math_hw4_code.pdf"]

merger =  PdfWriter()

for pdf in pdf_files:
    merger.append(pdf)

# 保存合并后的文件
merger.write(r"C:\Users\86182\Desktop\math_hw4_all.pdf")
merger.close()

print("合并完成：merged.pdf")
# Out:
# 合并完成：merged.pdf
